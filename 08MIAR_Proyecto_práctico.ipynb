# %% [markdown]
# # Actividad - Proyecto práctico
#
#
# > La actividad se desarrollará en grupos pre-definidos de 2-3 alumnos. Se debe indicar los nombres en orden alfabético (de apellidos). Recordad que esta actividad se corresponde con un 30% de la nota final de la asignatura. Se debe entregar entregar el trabajo en la presente notebook.
# *   Alumno 1:
# *   Alumno 2: Martín Jerónimo, Manuel
# *   Alumno 3: Velasco Romero, Álvaro

# %% [markdown]
# ---
# ## **PARTE 1** - Instalación y requisitos previos
#
# > Las prácticas han sido preparadas para poder realizarse en el entorno de trabajo de Google Colab. Sin embargo, esta plataforma presenta ciertas incompatibilidades a la hora de visualizar la renderización en gym. Por ello, para obtener estas visualizaciones, se deberá trasladar el entorno de trabajo a local. Por ello, el presente dosier presenta instrucciones para poder trabajar en ambos entornos. Siga los siguientes pasos para un correcto funcionamiento:
# 1.   **LOCAL:** Preparar el enviroment, siguiendo las intrucciones detalladas en la sección *1.1.Preparar enviroment*.
# 2.  **AMBOS:** Modificar las variables "mount" y "drive_mount" a la carpeta de trabajo en drive en el caso de estar en Colab, y ejecturar la celda *1.2.Localizar entorno de trabajo*.
# 3. **COLAB:** se deberá ejecutar las celdas correspondientes al montaje de la carpeta de trabajo en Drive. Esta corresponde a la sección *1.3.Montar carpeta de datos local*.
# 4.  **AMBOS:** Instalar las librerías necesarias, siguiendo la sección *1.4.Instalar librerías necesarias*.

# %% [markdown]
# ---
# ### 1.1. Preparar enviroment (solo local)
#
#
#
# > Para preparar el entorno de trabajo en local, se han seguido los siguientes pasos:
# 1. En Windows, puede ser necesario instalar las C++ Build Tools. Para ello, siga los siguientes pasos: https://towardsdatascience.com/how-to-install-openai-gym-in-a-windows-environment-338969e24d30.
# 2. Instalar Anaconda
# 3. Siguiendo el código que se presenta comentado en la próxima celda: Crear un enviroment, cambiar la ruta de trabajo, e instalar librerías básicas.
#
#
# ```
# conda create --name miar_rl python=3.8
# conda activate miar_rl
# cd "PATH_TO_FOLDER"
# conda install git
# pip install jupyter
# ```
#
#
# 4. Abrir la notebook con *jupyter-notebook*.
#
#
#
# ```
# jupyter-notebook
# ```

# %% [markdown]
# ---
# ### 1.2. Localizar entorno de trabajo: Google colab o local

# %%
try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False

drive_root = "/content/drive/MyDrive/08MIAR_Proyecto_Programación/"

# %% [markdown]
# ---
# ### 1.3. Montar carpeta de datos local (solo Colab)

# %%
# Switch to the directory on the Google Drive that you want to use
import os
if IN_COLAB:
  print("We're running Colab")

  if IN_COLAB:
    # Mount the Google Drive at mount
    print("Colab: mounting Google drive on ", drive_root)

    drive.mount('/content/drive')

    # Create drive_root if it doesn't exist
    create_drive_root = True
    if create_drive_root:
      print("\nColab: making sure ", drive_root, " exists.")
      os.makedirs(drive_root, exist_ok=True)
    
    # Change to the directory
    print("\nColab: Changing directory to ", drive_root)
    # %cd $drive_root
# Verify we're in the correct working directory
# %pwd
print("Archivos en el directorio: ")
print(os.listdir())

# %% [markdown]
# ---
# ### 1.4. Instalar librerías necesarias

# %%
if IN_COLAB:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install keras-rl2==1.0.5
  # %pip install tensorflow==2.8
else:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install pyglet==1.5.0
  # %pip install h5py==3.1.0
  # %pip install Pillow==9.5.0
  # %pip install keras-rl2==1.0.5
  # %pip install Keras==2.2.4
  # %pip install tensorflow==2.5.3
  # %pip install torch==2.0.1
  # %pip install agents==1.4.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 23.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 58.4 MB/s eta 0:00:00
# ...
#   Created wheel for gym: filename=gym-0.17.3-py3-none-any.whl size=1654622 sha256=b3a5743b1297446b2caf03ac847dc9aaae3c98ef4a553c3e76d9cd42b721c523
#   Stored in directory: /root/.cache/pip/wheels/af/4b/74/fcfc8238472c34d7f96508a63c962ff3ac9485a9a4137afd4e
# Successfully built gym
# ...
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 2.2.1
#     Uninstalling cloudpickle-2.2.1:
#       Successfully uninstalled cloudpickle-2.2.1
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
# ...

# %% [markdown]
# ---
# ## **PARTE 2**. Enunciado
#
# Consideraciones a tener en cuenta:
#
# - El entorno sobre el que trabajaremos será _SpaceInvaders-v0_ y el algoritmo que usaremos será _DQN_.
#
# - Para nuestro ejercicio, una solución óptima será alcanzada cuando el agente consiga una **media de recompensa por encima de 20 puntos en modo test**. Por ello, esta media de la recompensa se calculará a partir del código de test en la última celda del notebook.
#
# Este proyecto práctico consta de tres partes:
#
# 1.   Implementar la red neuronal que se usará en la solución
# 2.   Implementar las distintas piezas de la solución DQN
# 3.   Justificar la respuesta en relación a los resultados obtenidos
#
# IMPORTANTE:
#
# * Si no se consigue una puntuación óptima, responder sobre la mejor puntuación obtenida.
# * Para entrenamientos largos, recordad que podéis usar checkpoints de vuestros modelos para retomar los entrenamientos. En este caso, recordad cambiar los parámetros adecuadamente (sobre todo los relacionados con el proceso de exploración).

# %% [markdown]
# ---
# ## **PARTE 3**. Desarrollo y preguntas

# %% [markdown]
# #### Importar librerías

# %%
from __future__ import division

from PIL import Image
import numpy as np
import gym

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, GlobalAveragePooling2D, Flatten, MaxPooling2D, Dropout, Convolution2D, Permute
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import LearningRateScheduler

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

# %% [markdown]
# #### Configuración base

# %% [markdown]
# Estas celdas son comunes para todos los modelos probados para el presente proyecto.:

# %%
INPUT_SHAPE = (84, 84)
WINDOW_LENGTH = 4

env_name = 'SpaceInvaders-v0'
env = gym.make(env_name)

np.random.seed(123)
env.seed(123)

nb_actions = env.action_space.n

print(f"Numero de acciones disponibles: {nb_actions}")
print(f"Formato de las observaciones: {env.observation_space}")
# Out:
# Numero de acciones disponibles: 6
# Formato de las observaciones: Box(0, 255, (210, 160, 3), uint8)

# %%
class AtariProcessor(Processor):
    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)
        img = Image.fromarray(observation)
        img = img.resize(INPUT_SHAPE).convert('L')
        processed_observation = np.array(img)
        assert processed_observation.shape == INPUT_SHAPE
        return processed_observation.astype('uint8')

    def process_state_batch(self, batch):
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return np.clip(reward, -1., 1.)

# %% [markdown]
# ---
# ### **MODELO 1**. GlobalAveragePooling2D y 2 Capas Densas

# %% [markdown]
# 1. Implementación de la red neuronal

# %%
# Building our model.
input_shape = (WINDOW_LENGTH,) + INPUT_SHAPE
model = Sequential()

print(K.image_data_format())
if K.image_data_format() == 'channels_last':
    # (width, height, channels)
    model.add(Permute((2, 3, 1), input_shape=input_shape))
elif K.image_data_format() == 'channels_first':
    # (channels, width, height)
    model.add(Permute((1, 2, 3), input_shape=input_shape))
else:
    raise RuntimeError('Unknown image_dim_ordering.')

model.add(Convolution2D(64, (8, 8), strides=(4, 4), activation='relu'))
model.add(Convolution2D(128, (4, 4), strides=(2, 2), activation='relu'))
model.add(Convolution2D(256, (3, 3), strides=(1, 1), activation='relu'))
#model.add(Flatten())
model.add(GlobalAveragePooling2D())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(256, activation='relu'))
model.add(Dense(nb_actions, activation='linear'))

model.summary()
# Out:
# channels_last
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  permute (Permute)           (None, 84, 84, 4)         0
#
#  conv2d (Conv2D)             (None, 20, 20, 64)        16448
#
#  conv2d_1 (Conv2D)           (None, 9, 9, 128)         131200
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 256)         295168
#
#  global_average_pooling2d (G  (None, 256)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               131584
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 6)                 1542
#
# ...
# Total params: 707,270
# Trainable params: 707,270
# Non-trainable params: 0
# _________________________________________________________________

# %%
memory = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)

processor = AtariProcessor()

# %%
# La policy más relevante de DQN
policy = LinearAnnealedPolicy(EpsGreedyQPolicy(), attr='eps',
                              value_max=1., value_min=.1, value_test=.05,
                              nb_steps=1000000)

# %%
dqn = DQNAgent(model=model, nb_actions=nb_actions, policy=policy,
               memory=memory, processor=processor,
               nb_steps_warmup=50000, gamma=.99,
               target_model_update=10000, # esta congelada y se actualiza cada 10000
               train_interval=4)

dqn.compile(Adam(learning_rate=.00025), metrics=['mae'])

# %% [markdown]
# > Comenzamos el entrenamiento del modelo:

# %%
weights_filename = 'dqn_{}_weights.h5f'.format(env_name)
checkpoint_weights_filename = 'dqn_' + env_name + '_weights_{step}.h5f'
log_filename = 'dqn_{}_log.json'.format(env_name)

callbacks = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=250000)]
callbacks += [FileLogger(log_filename, interval=100)]

dqn.fit(env, callbacks=callbacks, nb_steps=1750000, log_interval=10000, visualize=False)

dqn.save_weights(weights_filename, overwrite=True)
# Out:
# Training for 1750000 steps ...
# Interval 1 (0 steps performed)
#     7/10000 [..............................] - ETA: 1:26 - reward: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 10000/10000 [==============================] - 77s 8ms/step - reward: 0.0141
# 14 episodes - episode_reward: 9.857 [5.000, 31.000] - ale.lives: 2.018
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: 0.0120
# 15 episodes - episode_reward: 7.933 [2.000, 15.000] - ale.lives: 2.136
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 80s 8ms/step - reward: 0.0142
# 15 episodes - episode_reward: 9.067 [5.000, 17.000] - ale.lives: 2.034
#
# Interval 4 (30000 steps performed)
# ...

# %%
# Continuar entrenamiento a partir de la época 500K hasta la época 1,25M...
policy = LinearAnnealedPolicy(EpsGreedyQPolicy(), attr='eps',
                              value_max=.555, value_min=.1, value_test=.05, # Actualizamos el epsilon de partida
                              nb_steps=1000000)

dqn = DQNAgent(model=model, nb_actions=nb_actions, policy=policy,
               memory=memory, processor=processor,
               nb_steps_warmup=30000,
               gamma=.99,
               target_model_update=10000,
               train_interval=4)

dqn.compile(Adam(learning_rate=.00025), metrics=['mae'])

weights_filename = '/content/drive/MyDrive/08MIAR_Proyecto_Programación/dqn_SpaceInvaders-v0_weights_500000.h5f'
dqn.load_weights(weights_filename)

# Training part
weights_filename = 'dqn_{}_weights.h5f'.format(env_name)
checkpoint_weights_filename = 'dqn_' + env_name + '_weights_{step}.h5f'
log_filename = 'dqn_{}_log.json'.format(env_name)

callbacks = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=250000)]
callbacks += [FileLogger(log_filename, interval=100)]

dqn.fit(env, callbacks=callbacks, nb_steps=1250000, log_interval=10000, visualize=False)
# Out:
# Training for 1250000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 306s 31ms/step - reward: 0.0182
# 11 episodes - episode_reward: 15.727 [4.000, 22.000] - loss: 0.007 - mae: 0.845 - mean_q: 1.018 - mean_eps: 0.552 - ale.lives: 1.997
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 330s 33ms/step - reward: 0.0200
# 12 episodes - episode_reward: 16.000 [4.000, 24.000] - loss: 0.007 - mae: 0.886 - mean_q: 1.066 - mean_eps: 0.548 - ale.lives: 2.063
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 329s 33ms/step - reward: 0.0208
# 13 episodes - episode_reward: 16.385 [7.000, 27.000] - loss: 0.007 - mae: 0.927 - mean_q: 1.115 - mean_eps: 0.544 - ale.lives: 2.039
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 335s 34ms/step - reward: 0.0226
# ...

# %%
# Continuar entrenamiento a partir de la época 1,25M hasta 2M...
policy = LinearAnnealedPolicy(EpsGreedyQPolicy(), attr='eps',
                              value_max=.216, value_min=.1, value_test=.05, # Actualizamos el epsilon de partida
                              nb_steps=1000000)

dqn = DQNAgent(model=model, nb_actions=nb_actions, policy=policy,
               memory=memory, processor=processor,
               nb_steps_warmup=20000,
               gamma=.99,
               target_model_update=10000,
               train_interval=4)

dqn.compile(Adam(learning_rate=.00025), metrics=['mae'])

weights_filename = f'{drive_root}dqn_SpaceInvaders-v0_weights_1_25M.h5f'
dqn.load_weights(weights_filename)

# Training part
weights_filename = f'{drive_root}dqn_{env_name}_weights.h5f'
checkpoint_weights_filename = drive_root + 'dqn_' + env_name + '_weights_{step}.h5f'
log_filename = f'{drive_root}dqn_{env_name}_log.json'

callbacks = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=250000)]
callbacks += [FileLogger(log_filename, interval=100)]

dqn.fit(env, callbacks=callbacks, nb_steps=750000, log_interval=10000, visualize=False)
# Out:
# Training for 750000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 49s 5ms/step - reward: 0.0247
# 13 episodes - episode_reward: 18.231 [6.000, 31.000] - ale.lives: 2.040
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 49s 5ms/step - reward: 0.0231
# 13 episodes - episode_reward: 16.538 [6.000, 27.000] - ale.lives: 1.835
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 334s 33ms/step - reward: 0.0191
# 12 episodes - episode_reward: 17.500 [6.000, 27.000] - loss: 0.013 - mae: 2.512 - mean_q: 3.016 - mean_eps: 0.213 - ale.lives: 2.108
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 340s 34ms/step - reward: 0.0211
# 12 episodes - episode_reward: 16.333 [5.000, 27.000] - loss: 0.012 - mae: 2.533 - mean_q: 3.042 - mean_eps: 0.212 - ale.lives: 1.948
#
# Interval 5 (40000 steps performed)
# ...

# %% [markdown]
# 2. Implementación de la solución DQN

# %% [markdown]
# Hemos realizado diversas pruebas de rendimiento cargando los pesos obtenidos en la última época de entrenamiento pero los resultados no son tan buenos como los pesos obtenidos en la época 1,5M donde en varias ocasiones conseguimos medias por encima de 20 puntos tras 10 episodios:

# %%
# Testing part to calculate the mean reward
weights_filename = f'{drive_root}dqn_SpaceInvaders-v0_weights_1_5M.h5f'
dqn.load_weights(weights_filename)
dqn.test(env, nb_episodes=10, visualize=False)
# Out:
# Testing for 10 episodes ...
# Episode 1: reward: 27.000, steps: 1120
# Episode 2: reward: 25.000, steps: 844
# Episode 3: reward: 21.000, steps: 1157
# Episode 4: reward: 23.000, steps: 986
# Episode 5: reward: 20.000, steps: 754
# Episode 6: reward: 15.000, steps: 643
# Episode 7: reward: 19.000, steps: 774
# Episode 8: reward: 26.000, steps: 933
# Episode 9: reward: 19.000, steps: 984
# Episode 10: reward: 33.000, steps: 1237

# %%
# Testing part to calculate the mean reward
weights_filename = f'{drive_root}dqn_SpaceInvaders-v0_weights_1_5M.h5f'
dqn.load_weights(weights_filename)
dqn.test(env, nb_episodes=10, visualize=False)
# Out:
# Testing for 10 episodes ...
# Episode 1: reward: 33.000, steps: 1200
# Episode 2: reward: 19.000, steps: 795
# Episode 3: reward: 19.000, steps: 750
# Episode 4: reward: 13.000, steps: 672
# Episode 5: reward: 25.000, steps: 994
# Episode 6: reward: 21.000, steps: 1007
# Episode 7: reward: 27.000, steps: 1369
# Episode 8: reward: 23.000, steps: 773
# Episode 9: reward: 21.000, steps: 900
# Episode 10: reward: 25.000, steps: 999

# %% [markdown]
# > Medias obtenidas en los ejemplos anteriores:
# - <b>Media: 22,8</b> - Mínimo: 15 - Máximo: 33
# - <b>Media: 22,6</b> - Mínimo: 13 - Máximo: 33

# %% [markdown]
# Por alguna razón a partir de la época 1,75M el rendimiento del modelo se desploma y lo hace peor que con apenas 500K épocas. El comportamiento del agente es muy pasivo apenas dispara y se mueve cuando anteriormente se le podía ver incluso completando el primer nivel, disparando a cada segundo y buscando coberturas.

# %%
weights_filename = f'{drive_root}dqn_SpaceInvaders-v0_weights_1_75M.h5f'
dqn.load_weights(weights_filename)
dqn.test(env, nb_episodes=10, visualize=False)
# Out:
# Testing for 10 episodes ...
# Episode 1: reward: 1.000, steps: 660
# Episode 2: reward: 0.000, steps: 672
# Episode 3: reward: 0.000, steps: 613
# Episode 4: reward: 1.000, steps: 659
# Episode 5: reward: 1.000, steps: 645
# Episode 6: reward: 0.000, steps: 642
# Episode 7: reward: 2.000, steps: 661
# Episode 8: reward: 1.000, steps: 690
# Episode 9: reward: 0.000, steps: 709
# Episode 10: reward: 1.000, steps: 380

# %%
weights_filename = f'{drive_root}dqn_SpaceInvaders-v0_weights_500K.h5f'
dqn.load_weights(weights_filename)
dqn.test(env, nb_episodes=10, visualize=False)
# Out:
# Testing for 10 episodes ...
# Episode 1: reward: 11.000, steps: 914
# Episode 2: reward: 5.000, steps: 612
# Episode 3: reward: 11.000, steps: 701
# Episode 4: reward: 13.000, steps: 936
# Episode 5: reward: 11.000, steps: 659
# Episode 6: reward: 15.000, steps: 1218
# Episode 7: reward: 9.000, steps: 686
# Episode 8: reward: 10.000, steps: 642
# Episode 9: reward: 12.000, steps: 930
# Episode 10: reward: 11.000, steps: 899

# %% [markdown]
# 3. Justificación de los parámetros seleccionados y de los resultados obtenidos

# %% [markdown]
# ---
# ### **MODELO 2**. MaxPooling2D y solo una Capa Densa

# %%
 #Definir una función para actualizar el learning rate
def lr_schedule(epoch):
    initial_lr = 0.00021  # Learning rate inicial
    factor = 0.5  # Factor de aumento del learning rate
    num_epochs_to_increase = 5  # Número de épocas para aumentar el learning rate
    new_lr = initial_lr * (factor ** (epoch // num_epochs_to_increase))
    return new_lr

# Crear el callback del LearningRateScheduler
lr_callback = LearningRateScheduler(lr_schedule)

# %% [markdown]
# 1. Implementación de la red neuronal

# %%
convnet = Sequential()
_input_shape = (WINDOW_LENGTH,) + INPUT_SHAPE
# 2D Convolution layer 1
convnet.add(layers.Conv2D(32, (8, 8),padding='same', activation='relu', input_shape=_input_shape)) 
convnet.add(layers.MaxPooling2D((2, 2))) 

# 2D Convolution layer 2
convnet.add(layers.Conv2D(64, (4, 4),padding='same', activation='relu'))
convnet.add(layers.MaxPooling2D((2, 2)))

# 2D Convolution layer 3
convnet.add(layers.Conv2D(64, (3, 3),padding='same', activation='relu'))

# Primer (y único) set de capas FC => RELU
convnet.add(layers.Flatten()) 
convnet.add(layers.Dense(512, activation='relu'))

#Add Output Layer
convnet.add(layers.Dense(nb_actions, activation='linear'))

print(convnet.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 16, 84, 32)        172064
#
#  max_pooling2d (MaxPooling2D  (None, 8, 42, 32)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 8, 42, 64)         32832
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 21, 64)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 21, 64)         36928
#
#  flatten (Flatten)           (None, 5376)              0
#
#  dense (Dense)               (None, 512)               2753024
#
#  dense_1 (Dense)             (None, 6)                 3078
#
# ...
# Total params: 2,997,926
# Trainable params: 2,997,926
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# 2. Implementación de la solución DQN

# %%
memory = SequentialMemory(limit=100000, window_length=WINDOW_LENGTH)
processor = AtariProcessor()

# %%
policy = LinearAnnealedPolicy(EpsGreedyQPolicy(), attr='eps',
                              value_max=1., value_min=.1, value_test=.05,
                              nb_steps=100000)

policy = BoltzmannQPolicy(tau=0.2)

# %%
dqn = DQNAgent(model=convnet, nb_actions=nb_actions, policy=policy,
               memory=memory, processor=processor,
               nb_steps_warmup=50000, gamma=.20,
               target_model_update=1000,
               train_interval=512)
dqn.compile(Adam(learning_rate=.000025), metrics=['mae'])

# %%
# Training part
weights_filename = 'dqn_{}_weights.h5f'.format(env_name)
checkpoint_weights_filename = 'dqn_' + env_name + '_weights_{step}.h5f'
log_filename = 'dqn_{}_log.json'.format(env_name)
callbacks = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=250000)]
callbacks += [FileLogger(log_filename, interval=100)]

dqn.fit(env, callbacks=callbacks, nb_steps=1750000, log_interval=10000, visualize=False)

dqn.save_weights(weights_filename, overwrite=True)
# Out:
# Training for 1750000 steps ...
# Interval 1 (0 steps performed)
#    13/10000 [..............................] - ETA: 1:31 - reward: 0.0000e+00
# C:\Users\drj_r\anaconda3\envs\miar_rl\lib\site-packages\tensorflow\python\keras\engine\training.py:2424: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0154
# 14 episodes - episode_reward: 10.500 [5.000, 19.000] - ale.lives: 2.222
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 116s 12ms/step - reward: 0.0133
# 16 episodes - episode_reward: 8.250 [2.000, 14.000] - ale.lives: 2.107
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 119s 12ms/step - reward: 0.0150
# ...

# %%
# Testing part to calculate the mean reward
weights_filename = 'dqn_{}_weights.h5f'.format(env_name)
dqn.load_weights(weights_filename)
dqn.test(env, nb_episodes=10, visualize=True)
# Out:
# Testing for 10 episodes ...
# Episode 1: reward: 7.000, steps: 638
# Episode 2: reward: 22.000, steps: 986
# Episode 3: reward: 18.000, steps: 1387
# Episode 4: reward: 13.000, steps: 840
# Episode 5: reward: 10.000, steps: 779
# Episode 6: reward: 12.000, steps: 804
# Episode 7: reward: 6.000, steps: 395
# Episode 8: reward: 10.000, steps: 787
# Episode 9: reward: 12.000, steps: 857
# Episode 10: reward: 8.000, steps: 662

# %% [markdown]
# 3. Justificación de los parámetros seleccionados y de los resultados obtenidos
#
# En este trabajo, hemos explorado diferentes estrategias de resolución del problema y hemos analizado sus ventajas e inconvenientes. En nuestra aproximación, nos hemos inspirado en los conceptos vistos en clase para abordar el desafío. Para comprender mejor las decisiones tomadas al parametrizar nuestro modelo, es importante comprender cómo se desarrolla el juego.
#
# Las mayores recompensas se obtienen al eliminar la mayor cantidad posible de enemigos, los cuales se mueven constantemente y disparan. Consideramos que utilizar solo una ventana de 4 imágenes no sería suficiente para captar información sobre la dirección de movimiento de los enemigos, si están descendiendo o si están disparando. Por lo tanto, decidimos utilizar una línea temporal más larga para tener una mejor perspectiva y mejorar nuestras predicciones.
#
# En cuanto a la selección de la política de acción, optamos por la BoltzmannQPolicy con un valor de tau de 0.2. Un valor más alto de tau haría que las acciones se seleccionen de manera más aleatoria, mientras que un valor más bajo daría más prioridad a las acciones prometedoras. No queríamos tomar decisiones demasiado aleatorias y preferimos dar más importancia a las acciones que se consideran más prometedoras. Dado que no estamos tratando con un entorno que tiene una gran cantidad de acciones posibles, no necesitamos explorar de manera exhaustiva.
#
# Otro factor que ajustamos para buscar una mayor puntuación fue la gamma, establecida en 0.20. Un valor bajo hace que las recompensas inmediatas tengan más peso que las futuras. Dado que nuestro objetivo era relativamente bajo, consideramos que sería beneficioso obtener múltiples recompensas altas rápidamente, como eliminar a varios enemigos antes de realizar cualquier movimiento.
#
# Si bien en la etapa de prueba logramos superar el objetivo en una ocasión, en los demás casos no lo conseguimos. El promedio de puntuación se situó por debajo de nuestras expectativas. Quizás podríamos plantear una estrategia más conservadora que permita obtener pequeñas recompensas de forma constante a lo largo del tiempo

# %% [markdown]
# ---
# ## **PARTE 4**. Conclusiones

# %% [markdown]
# ---
